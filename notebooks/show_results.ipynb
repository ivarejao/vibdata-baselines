# %%
import pandas as pd

pd.options.display.max_rows = 1000
df = pd.read_csv('results.csv')
df.groupby(['dataset_name','norm_type','domain','classifier_name']).nth(0)[['test_accuracy']]
# Out:
#                                                   test_accuracy
# dataset_name norm_type domain    classifier_name
# cwru         -1-1      frequency AlexNet               0.931034
#                                  CNN                   0.957854
#                                  LeNet                 0.984674
#                                  MLP                   1.000000
#                        time      AlexNet               0.180077
#                                  CNN                   0.904215
#                                  LeNet                 0.816092
#                                  MLP                   0.674330
#              0-1       frequency AlexNet               0.965517
#                                  CNN                   0.969349
#                                  LeNet                 0.950192
#                                  MLP                   1.000000
#                        time      AlexNet               0.180077
# ...
